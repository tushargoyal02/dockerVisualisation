# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
from pyspark import SparkContext,SparkConf

# %%
conf = SparkConf().setAppName("lo").setMaster("local")

# %%
sc.stop()
sc = SparkContext(conf=conf)

# %%
rd = sc.textFile("/home/tushar/Desktop/gitRepos/ML/output.json")

# %%
data=rd.flatMap(lambda x: x.split(","))
#data = rd.map(lambda x : x.split(","))
data.collect()
#print(size)
#totalSize=900
#size = rd.map(lambda x: x.toString.length)
#size.collect()
#size = data.count()
#for i (size > size):
   # data.collect()
   # print("hello")
#for i in data.count():
#    data.collect()
    
#data.split(",")[11]
# Out:
# ['b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '',
#  'b\'{"read":"0001-01-01T00:00:00Z"',
#  '"preread":"0001-01-01T00:00:00Z"',
#  '"pids_stats":{}',
#  '"blkio_stats":{"io_service_bytes_recursive":null',
#  '"io_serviced_recursive":null',
#  '"io_queue_recursive":null',
#  '"io_service_time_recursive":null',
#  '"io_wait_time_recursive":null',
#  '"io_merged_recursive":null',
#  '"io_time_recursive":null',
#  '"sectors_recursive":null}',
#  '"num_procs":0',
#  '"storage_stats":{}',
#  '"cpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"precpu_stats":{"cpu_usage":{"total_usage":0',
#  '"usage_in_kernelmode":0',
#  '"usage_in_usermode":0}',
#  '"throttling_data":{"periods":0',
#  '"throttled_periods":0',
#  '"throttled_time":0}}',
#  '"memory_stats":{}',
#  '"name":"/inspiring_bardeen"',
#  '"id":"fb2b91491aa8837917600c73aa537ffade3f419dafb1947bb3727821d202029f"}\\n\'',
#  '']

# %%
#mport time
#for i in data.collect():
 #  time.sleep(1)
 #   print(i)

# %%
stopwords = ["cpu_stats:{cpu_usage:{total_usage:0 "]
rdd3 = data.filter(lambda x: x in stopwords)
rdd3.take(0)
# Out:
# []

# %%
rdd4 = sc.textFile("/home/tushar/Desktop/gitRepos/ML/show.json")

# %%
#rdd5=rdd4.collect()
#print(type(rdd5))

# %%
list1=[]
rdd5 = rdd4.flatMap(lambda x: x.split(","))

abc=rdd5.collect()[0]
print(type(abc))
percu_list=[]
for num in rdd5.collect():
    if 'percpu' in num:
        percpu=num.split("[")[1]
        percu_list.append(int(percpu))
        #print(type(percpu))

        #print(num)
print(percu_list,type(percu_list[1]))
#print(list1)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# [4488914976, 4488914976, 4488914976, 4488914976, 4488914976, 4488914976, 4488914976, 4605562985, 4488914976, 4627612410, 4605562985, 4628219775, 4627612410, 4628721993, 4628219775, 4628920588, 4628721993, 4628920588, 4628920588, 4628920588, 4628920588, 4628920588, 4628920588, 4629015132, 4628920588, 4629015132, 4629015132, 4629015132, 4629015132, 4629050145, 4629015132, 4629395417, 4629050145, 4488914976, 4488914976, 4488914976, 4488914976, 4488914976, 4488914976, 4488914976, 4605562985, 4488914976, 4627612410, 4605562985, 4628219775, 4627612410, 4628721993, 4628219775, 4628920588, 4628721993, 4628920588, 4628920588, 4628920588, 4628920588, 4628920588, 4628920588, 4629015132, 4628920588, 4629015132, 4629015132, 4629015132, 4629015132, 4629050145, 4629015132, 4629395417, 4629050145] <class 'int'>

# %%
print(list,type(list))
# Out:
# ['b', "'", '{', '"', 'r', 'e', 'a', 'd', '"', ':', '"', '2', '0', '1', '9', '-', '0', '2', '-', '1', '8', 'T', '1', '5', ':', '1', '0', ':', '4', '0', '.', '2', '8', '8', '9', '4', '5', '6', '4', '4', 'Z', 'p', 'r', 'e', 'r', 'e', 'a', 'd', '"', ':', '"', '0', '0', '0', '1', '-', '0', '1', '-', '0', '1', 'T', '0', '0', ':', '0', '0', ':', '0', '0', 'Z', 'p', 'i', 'd', 's', '_', 's', 't', 'a', 't', 's', '"', ':', '{', '"', 'c', 'u', 'r', 'r', 'e', 'n', 't', '"', ':', '9', '}', 'b', 'l', 'k', 'i', 'o', '_', 's', 't', 'a', 't', 's', '"', ':', '{', '"', 'i', 'o', '_', 's', 'e', 'r', 'v', 'i', 'c', 'e', '_', 'b', 'y', 't', 'e', 's', '_', 'r', 'e', 'c', 'u', 'r', 's', 'i', 'v', 'e', '"', ':', '[', '{', '"', 'm', 'a', 'j', 'o', 'r', '"', ':', '8', 'm', 'i', 'n', 'o', 'r', '"', ':', '0', 'o', 'p', '"', ':', '"', 'R', 'e', 'a', 'd', 'v', 'a', 'l', 'u', 'e', '"', ':', '1', '2', '8', '3', '1', '1', '2', '9', '6', '}', '{', '"', 'm', 'a', 'j', 'o', 'r', '"', ':', '8', 'm', 'i', 'n', 'o', 'r', '"', ':', '0', 'o', 'p', '"', ':', '"', 'W', 'r', 'i', 't', 'e', 'v', 'a', 'l', 'u', 'e', '"', ':', '4', '0', '0', '1', '7', '9', '2', '}', '{', '"', 'm', 'a', 'j', 'o', 'r', '"', ':', '8', 'm', 'i', 'n', 'o', 'r', '"', ':', '0', 'o', 'p', '"', ':', '"', 'S', 'y', 'n', 'c', 'v', 'a', 'l', 'u', 'e', '"', ':', '2', '2', '4', '8', '7', '0', '4', '}', '{', '"', 'm', 'a', 'j', 'o', 'r', '"', ':', '8', 'm', 'i', 'n', 'o', 'r', '"', ':', '0', 'o', 'p', '"', ':', '"', 'A', 's', 'y', 'n', 'c', 'v', 'a', 'l', 'u', 'e', '"', ':', '1', '3', '0', '0', '6', '4', '3', '8', '4', '}', '{', '"', 'm', 'a', 'j', 'o', 'r', '"', ':', '8', 'm', 'i', 'n', 'o', 'r', '"', ':', '0', 'o', 'p', '"', ':', '"', 'T', 'o', 't', 'a', 'l', 'v', 'a', 'l', 'u', 'e', '"', ':', '1', '3', '2', '3', '1', '3', '0', '8', '8', '}', ']', 'i', 'o', '_', 's', 'e', 'r', 'v', 'i', 'c', 'e', 'd', '_', 'r', 'e', 'c', 'u', 'r', 's', 'i', 'v', 'e', '"', ':', '[', '{', '"', 'm', 'a', 'j', 'o', 'r', '"', ':', '8', 'm', 'i', 'n', 'o', 'r', '"', ':', '0', 'o', 'p', '"', ':', '"', 'R', 'e', 'a', 'd', 'v', 'a', 'l', 'u', 'e', '"', ':', '4', '0', '7', '3', '}', '{', '"', 'm', 'a', 'j', 'o', 'r', '"', ':', '8', 'm', 'i', 'n', 'o', 'r', '"', ':', '0', 'o', 'p', '"', ':', '"', 'W', 'r', 'i', 't', 'e', 'v', 'a', 'l', 'u', 'e', '"', ':', '9', '1', '0', '}', '{', '"', 'm', 'a', 'j', 'o', 'r', '"', ':', '8', 'm', 'i', 'n', 'o', 'r', '"', ':', '0', 'o', 'p', '"', ':', '"', 'S', 'y', 'n', 'c', 'v', 'a', 'l', 'u', 'e', '"', ':', '4', '8', '7', '}', '{', '"', 'm', 'a', 'j', 'o', 'r', '"', ':', '8', 'm', 'i', 'n', 'o', 'r', '"', ':', '0', 'o', 'p', '"', ':', '"', 'A', 's', 'y', 'n', 'c', 'v', 'a', 'l', 'u', 'e', '"', ':', '4', '4', '9', '6', '}', '{', '"', 'm', 'a', 'j', 'o', 'r', '"', ':', '8', 'm', 'i', 'n', 'o', 'r', '"', ':', '0', 'o', 'p', '"', ':', '"', 'T', 'o', 't', 'a', 'l', 'v', 'a', 'l', 'u', 'e', '"', ':', '4', '9', '8', '3', '}', ']', 'i', 'o', '_', 'q', 'u', 'e', 'u', 'e', '_', 'r', 'e', 'c', 'u', 'r', 's', 'i', 'v', 'e', '"', ':', '[', ']', 'i', 'o', '_', 's', 'e', 'r', 'v', 'i', 'c', 'e', '_', 't', 'i', 'm', 'e', '_', 'r', 'e', 'c', 'u', 'r', 's', 'i', 'v', 'e', '"', ':', '[', ']', 'i', 'o', '_', 'w', 'a', 'i', 't', '_', 't', 'i', 'm', 'e', '_', 'r', 'e', 'c', 'u', 'r', 's', 'i', 'v', 'e', '"', ':', '[', ']', 'i', 'o', '_', 'm', 'e', 'r', 'g', 'e', 'd', '_', 'r', 'e', 'c', 'u', 'r', 's', 'i', 'v', 'e', '"', ':', '[', ']', 'i', 'o', '_', 't', 'i', 'm', 'e', '_', 'r', 'e', 'c', 'u', 'r', 's', 'i', 'v', 'e', '"', ':', '[', ']', 's', 'e', 'c', 't', 'o', 'r', 's', '_', 'r', 'e', 'c', 'u', 'r', 's', 'i', 'v', 'e', '"', ':', '[', ']', '}', 'n', 'u', 'm', '_', 'p', 'r', 'o', 'c', 's', '"', ':', '0', 's', 't', 'o', 'r', 'a', 'g', 'e', '_', 's', 't', 'a', 't', 's', '"', ':', '{', '}', 'c', 'p', 'u', '_', 's', 't', 'a', 't', 's', '"', ':', '{', '"', 'c', 'p', 'u', '_', 'u', 's', 'a', 'g', 'e', '"', ':', '{', '"', 't', 'o', 't', 'a', 'l', '_', 'u', 's', 'a', 'g', 'e', '"', ':', '1', '1', '2', '5', '5', '8', '0', '3', ...

# %%
print(data)
# Out:
# None
